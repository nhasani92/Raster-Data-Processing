# %%
import pandas as pd
import geopandas as gpd

# %%
file = 'C:/Users/Nusrat/Desktop/Hrishabh/SLUM_LOCATION.csv'

# %%
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
slum = pd.read_csv(file,encoding='ISO-8859-1')
slum.head()
# Out:
#                         CITY        STATE   LATITUDE  LONGITUDE
# 0             Dharavi MUMBAI   MAHARASTRA  19.046597  72.859970
# 1        Nochikuppam CHANNAI   TAMIL NADU  13.037886  80.280229
# 2  Rajendra Nagar (Banglore)    KARNATAKA  12.949789  77.619234
# 3            Bhalswa (Delhi)     Delhi UT  28.735186  77.619234
# 4          Basanti (Kolkata)  WEST BANGAL  22.199375  88.715701

# %%
slum = gpd.GeoDataFrame(slum, geometry = gpd.points_from_xy(slum['LONGITUDE'],slum['LATITUDE'] ))
slum.plot(markersize = 1.5, figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
cities = gpd.read_file('C:/Users/Nusrat/Desktop/India Shapefile With Kashmir/India Shape/india_ds.shp')
cities.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>
